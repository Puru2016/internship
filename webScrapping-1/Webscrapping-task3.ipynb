# %% [markdown]
# # Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape and make data frame

# %% [markdown]
# # A) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.

# %%
#!pip install bs4
#!pip install requests

from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %%
page = requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')
soup = BeautifulSoup(page.content)
#print(soup.prettify())

#findtable = soup.find('table')
findtable = soup.find('table', {'class': 'table'})

# Getting all rows
data = []
for row in findtable.find_all('tr'):
    row_data = []
    for cell in row.find_all('td'):
        row_data.append(cell.text.replace("\n", ""))
    data.append(row_data)

#data

# %%
# Making Dataframe
df = pd.DataFrame(data)
df.drop(index=0)
df.columns = ['S. No', 'CountryName', 'Matches', 'Points', 'Rating']
df = df.head(11)
df
# Out:
#    S. No     CountryName Matches Points  \
# 0   None            None    None   None
# 1      1    AustraliaAUS      27  3,112
# 2      2     PakistanPAK      27  3,102
# 3      3        IndiaIND      40  4,558
# 4      4      EnglandENG      28  2,942
# 5      5  South AfricaSA      23  2,386
# 6      6   New ZealandNZ      31  3,110
# 7      7   BangladeshBAN      33  3,107
# 8      8     Sri LankaSL      37  3,448
# 9      9  AfghanistanAFG      21  1,687
# 10    10   West IndiesWI      38  2,582
#
#                                                Rating
# 0                                                None
# 1                               115               ...
# 2                                                 115
# 3                                                 114
# 4                                                 105
# 5                                                 104
# 6                                                 100
# 7                                                  94
# 8                                                  93
# 9                                                  80
# 10                                                 68

# %% [markdown]
# # B) Top 10 ODI Batsmen along with the records of their team andrating.

# %%
page2 = requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting')
soup2 = BeautifulSoup(page2.content)
#print(soup2.prettify())

#findtable = soup2.find('table')
batsmanTable = soup2.find('table', {'class': 'table rankings-table'})


# Getting all rows
batsmandata = []
for i in batsmanTable.find_all('tr'):
    bman_data = []
    for cell in i.find_all('td'):
        bman_data.append(cell.text.replace("\n", ""))
    batsmandata.append(bman_data)

#batsmandata

# %%
# Making Dataframe
my_df = pd.DataFrame(batsmandata)

my_df.drop(columns=[my_df.columns[4]], inplace=True)
my_df.drop(index=my_df.index[0], axis=0, inplace=True)

my_df.columns = ['S. No', 'Player Name', 'TEam', 'Rating']
my_df = my_df.head(10)
my_df
# Out:
#                                                 S. No            Player Name  \
# 1                               1                 ...             Babar Azam
# 2                                       2         ...           Shubman Gill
# 3                                       3         ...  Rassie van der Dussen
# 4                                       4         ...           David Warner
# 5                                       5         ...            Imam-ul-Haq
# 6                                       6         ...           Harry Tector
# 7                                       7         ...        Quinton de Kock
# 8                                       8         ...            Virat Kohli
# 9                                       9         ...           Rohit Sharma
# 10                                      10        ...           Fakhar Zaman
#
#                        TEam Rating
# 1   PAK                        863
# 2                       IND    759
# 3                        SA    745
# 4                       AUS    739
# 5                       PAK    735
# 6                       IRE    726
# 7                        SA    721
# 8                       IND    715
# 9                       IND    707
# 10                      PAK    705

# %% [markdown]
# # c) Top 10 ODI bowlers along with the records of their team andrating.

# %%
page3 = requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling')
soup3 = BeautifulSoup(page3.content)
#print(soup2.prettify())

bowlerTable = soup3.find('table', {'class': 'table rankings-table'})


# Getting all rows
bowlerdata = []
for i in bowlerTable.find_all('tr'):
    bowl_data = []
    for cell in i.find_all('td'):
        bowl_data.append(cell.text.replace("\n", ""))
    bowlerdata.append(bowl_data)

#bowlerdata

# %%
# Making Dataframe
bowler_df = pd.DataFrame(bowlerdata)

bowler_df.drop(columns=[bowler_df.columns[4]], inplace=True)
bowler_df.drop(index=bowler_df.index[0], axis=0, inplace=True)

bowler_df.columns = ['S. No', 'Bowler Name', 'TEam', 'Rating']
bowler_df = bowler_df.head(10)
bowler_df
# Out:
#                                                 S. No       Bowler Name  \
# 1                               1                 ...    Josh Hazlewood
# 2                                       2         ...    Mitchell Starc
# 3                                       =         ...       Trent Boult
# 4                                       4         ...        Adam Zampa
# 5                                       5         ...        Matt Henry
# 6                                       6         ...  Mujeeb Ur Rahman
# 7                                       7         ...     Kuldeep Yadav
# 8                                       8         ...       Rashid Khan
# 9                                       9         ...    Mohammed Siraj
# 10                                      10        ...    Shaheen Afridi
#
#                        TEam Rating
# 1   AUS                        692
# 2                       AUS    666
# 3                        NZ    666
# 4                       AUS    663
# 5                        NZ    658
# 6                       AFG    657
# 7                       IND    656
# 8                       AFG    655
# 9                       IND    643
# 10                      PAK    635
