# %% [markdown]
# # Write a python program to scrape mentioned details from dineout.co.in and make data frame-

# %%
#!pip install bs4
#!pip install requests

from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

page = requests.get('https://www.dineout.co.in/delhi-restaurants/buffet-special')
soup = BeautifulSoup(page.content)

# Getting all Restaurant Name
restaurantName = []
for row in soup.find_all('div',class_="restnt-info cursor"):
    restaurantName.append(row.text)

# print values    
#restaurantName


# Getting all Cuisine
cuisine = []
for row in soup.find_all('span',class_="double-line-ellipsis"):
    res = re.split('\|', row.text)
    cuisine.append(res[1])

# print values 
#cuisine


# Getting all Location
location = []
for row in soup.find_all('div',class_="restnt-loc ellipsis"):
    location.append(row.text)

# print values     
#location

# Getting all Ratings
ratings = []
for row in soup.find_all('div',class_="restnt-rating rating-4"):
    ratings.append(row.text)


# print values 
#ratings

# Getting all Image URL
dataUrl = []
for row in soup.find_all("img",class_="no-img"):
    dataUrl.append(row['data-src'])

# print values
#dataUrl

# Making Dataframe
df = pd.DataFrame({'Restaurant name':restaurantName,'Cuisine':cuisine,'Location':location,'Ratings':ratings,'Image URL':dataUrl})
df
# Out:
#                                      Restaurant name  \
# 0      Castle BarbequeConnaught Place, Central Delhi
# 1  Cafe KnoshThe Leela Ambience Convention Hotel,...
# 2  Castle's BarbequePacific Mall,Tagore Garden, W...
# 3    India GrillHilton Garden Inn,Saket, South Delhi
# 4  The Barbeque CompanyGardens Galleria,Sector 38...
# 5  Delhi BarbequeTaurus Sarovar Portico,Mahipalpu...
# 6  The Monarch - Bar Be Que VillageIndirapuram Ha...
# 7  Indian Grill RoomSuncity Business Tower,Golf C...
# 8  The Barbeque TimesM2K Corporate Park,Sector 51...
#
#                                              Cuisine  \
# 0                              Chinese, North Indian
# 1                               Italian, Continental
# 2                              Chinese, North Indian
# 3                              North Indian, Italian
# 4                              North Indian, Chinese
# 5                                       North Indian
# 6                                       North Indian
# ...
