# %%
from selenium import webdriver
import time
from selenium.webdriver.support.select import Select

from selenium.webdriver.common.by import By

from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException

# %%
# connect to webdriver
driver = webdriver.Chrome()
driver.get("https://rentberry.com/apartments/115875014-one-br-11300-s-i-35-frontage-rd-unit-th8104")
#driver.get("https://rentberry.com/houses/117564603-three-br-807-meadowcreek-drive")

pro_add_array = []
pro_bed_array = []
property_bath_array = []
property_rent_array = []
property_area_array = []
property_dogs_array = []
property_cats_array = []
pro_deposit_array = []
pro_sn_array = []

property_deposit = driver.find_elements(By.XPATH,'/html/body/rb-core/div/rb-property/div/div/div/rb-property-main-info/section/div/div/rb-property-facilities/section/div[5]/span[2]')

for j in property_deposit:
    deposit = j.text
    pro_deposit_array.append(deposit) 

property_add = driver.find_elements(By.XPATH,'//div[@class="map-address font-m"]')

for j in property_add:
    address = j.text
    pro_add_array.append(address)    
    
property_bed = driver.find_elements(By.XPATH,'/html/body/rb-core/div/rb-property/div/div/div/rb-property-main-info/section/div/div/rb-property-facilities/section/div[1]/span[2]')

for j in property_bed:
    beds = j.text
    pro_bed_array.append(beds)

    
property_bath = driver.find_elements(By.XPATH,'/html/body/rb-core/div/rb-property/div/div/div/rb-property-main-info/section/div/div/rb-property-facilities/section/div[2]/span[2]')

for j in property_bath:
    bath = j.text
    property_bath_array.append(bath)
    
    
property_rent = driver.find_elements(By.XPATH,'//div[@class="font-l value rating-lower"]')

for j in property_rent:
    rent = j.text
    property_rent_array.append(rent)
    
property_area = driver.find_elements(By.XPATH,'/html/body/rb-core/div/rb-property/div/div/div/rb-property-main-info/section/div/div/rb-property-facilities/section/div[3]/span[2]')

for j in property_area:
    area = j.text
    property_area_array.append(area)
    
property_dogs = driver.find_elements(By.XPATH,'/html/body/rb-core/div/rb-property/div/div/div/rb-property-main-info/section/div/div/rb-property-facilities/section/div[4]/span[2]')

for j in property_dogs:
    dogs = j.text
    property_dogs_array.append(dogs)

    
property_cats = driver.find_elements(By.XPATH,'/html/body/rb-core/div/rb-property/div/div/div/rb-property-main-info/section/div/div/rb-property-facilities/section/div[5]/span[2]')

for j in property_cats:
    cats = j.text
    property_cats_array.append(cats)   

    
for j in range(len(property_add)):
    sn = j+1
    pro_sn_array.append(sn)
    
print(pro_deposit_array)
print(
    len(pro_sn_array),
    len(pro_add_array),
    len(pro_bed_array), 
    len(property_bath_array), 
    len(property_rent_array),
    len(property_area_array),
    len(property_dogs_array),
    len(property_cats_array),
    len(pro_deposit_array)
)

df = pd.DataFrame(zip(
    pro_sn_array,
    pro_add_array,
    pro_bed_array,    
    property_bath_array,
    property_rent_array,
    property_area_array,
    property_dogs_array,
    property_cats_array,
    pro_deposit_array
),columns=[
    'pro_sn_array',
    'pro_add_array',
    'pro_bed_array',
    'property_bath_array',
    'property_rent_array',
    'property_area_array',
    'property_dogs_array',
    'property_cats_array',
    'pro_deposit_array'
])

df.to_csv("/home/webepower/Downloads/Delete/table.csv",index=False)

# %%
# connect to webdriver
driver = webdriver.Chrome()
driver.get("https://rentberry.com/apartments/115875014-one-br-11300-s-i-35-frontage-rd-unit-th8104")

pro_sn_array = []
pro_bed_array = []
property_bath_array = []
property_area_array = []
property_dogs_array = []
property_cats_array = [] 
pro_sn_array = []    

    
property_bed = driver.find_elements(By.XPATH,'/html/body/rb-core/div/rb-property/div/div/div/rb-property-main-info/section/div/div/rb-property-facilities/section/div[1]/span[2]')

for j in property_bed:
    beds = j.text
    pro_bed_array.append(beds)

    
property_bath = driver.find_elements(By.XPATH,'/html/body/rb-core/div/rb-property/div/div/div/rb-property-main-info/section/div/div/rb-property-facilities/section/div[2]/span[2]')

for j in property_bath:
    bath = j.text
    property_bath_array.append(bath)
    
property_area = driver.find_elements(By.XPATH,'/html/body/rb-core/div/rb-property/div/div/div/rb-property-main-info/section/div/div/rb-property-facilities/section/div[3]/span[2]')

for j in property_area:
    area = j.text
    property_area_array.append(area)
    
property_dogs = driver.find_elements(By.XPATH,'/html/body/rb-core/div/rb-property/div/div/div/rb-property-main-info/section/div/div/rb-property-facilities/section/div[4]/span[2]')

for j in property_dogs:
    dogs = j.text
    property_dogs_array.append(dogs)

    
property_cats = driver.find_elements(By.XPATH,'/html/body/rb-core/div/rb-property/div/div/div/rb-property-main-info/section/div/div/rb-property-facilities/section/div[5]/span[2]')

for j in property_cats:
    cats = j.text
    property_cats_array.append(cats)
    
    
for j in range(len(property_bed)):
    sn = j+1
    pro_sn_array.append(sn)
    
print(pro_sn_array)
print(
    len(pro_sn_array),
    len(pro_bed_array), 
    len(property_bath_array),
    len(property_area_array),
    len(property_dogs_array),
    len(property_cats_array)
)

df = pd.DataFrame(zip(
    pro_sn_array,
    pro_bed_array,    
    property_bath_array,
    property_area_array,
    property_dogs_array,
    property_cats_array
),columns=[
    'pro_sn_array',
    'pro_bed_array',
    'property_bath_array',
    'property_area_array',
    'property_dogs_array',
    'property_cats_array'
])

df.to_csv("/home/webepower/Downloads/Delete/table2.csv",index=False)

# %%
# connect to webdriver
driver = webdriver.Chrome()
driver.get("https://rentberry.com/apartments/115875014-one-br-11300-s-i-35-frontage-rd-unit-th8104")

pro_sn_array = []
property_ac_array = []
property_bath_array = []
property_area_array = []
property_dogs_array = []
property_cats_array = [] 
pro_sn_array = []    

    
property_dishwasher = driver.find_elements(By.XPATH,'/html/body/rb-core/div/rb-property/div/div/div/rb-property-main-info/section/div/div/rb-property-facilities/section/div[1]/span[2]')

for j in property_dishwasher:
    dishwasher = j.text
    property_dishwasher_array.append(dishwasher)


property_hardwood = driver.find_elements(By.XPATH,'/html/body/rb-core/div/rb-property/div/div/div/rb-property-main-info/section/div/div/rb-property-facilities/section/div[1]/span[2]')

for j in property_hardwood:
    hardwood = j.text
    property_hardwood_array.append(hardwood)


property_fireplace = driver.find_elements(By.XPATH,'/html/body/rb-core/div/rb-property/div/div/div/rb-property-main-info/section/div/div/rb-property-facilities/section/div[2]/span[2]')

for j in property_fireplace:
    fireplace = j.text
    property_fireplace_array.append(fireplace)    
    
property_parking = driver.find_elements(By.XPATH,'/html/body/rb-core/div/rb-property/div/div/div/rb-property-main-info/section/div/div/rb-property-facilities/section/div[3]/span[2]')

for j in property_parking:
    parking = j.text
    property_parking_array.append(parking)
    
property_ac = driver.find_elements(By.XPATH,'/html/body/rb-core/div/rb-property/div/div/div/rb-property-main-info/section/div/div/rb-property-facilities/section/div[4]/span[2]')

for j in property_ac:
    ac = j.text
    property_ac_array.append(ac)
    
washer_dryer = driver.find_elements(By.XPATH,'/html/body/rb-core/div/rb-property/div/div/div/rb-property-main-info/section/div/div/rb-property-facilities/section/div[5]/span[2]')

for j in washer_dryer:
    washer = j.text
    washer_dryer_array.append(washer)
    
    
for j in range(len(property_bed)):
    sn = j+1
    pro_sn_array.append(sn)
    
print(pro_sn_array)
print(
    len(pro_sn_array),
    len(pro_bed_array), 
    len(property_bath_array),
    len(property_area_array),
    len(property_dogs_array),
    len(property_cats_array)
)

df = pd.DataFrame(zip(
    pro_sn_array,
    pro_bed_array,    
    property_bath_array,
    property_area_array,
    property_dogs_array,
    property_cats_array
),columns=[
    'pro_sn_array',
    'pro_bed_array',
    'property_bath_array',
    'property_area_array',
    'property_dogs_array',
    'property_cats_array'
])

df.to_csv("/home/webepower/Downloads/Delete/table3.csv",index=False)
