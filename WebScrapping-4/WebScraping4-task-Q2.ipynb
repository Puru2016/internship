# %% [markdown]
# # Q2: Scrape the details team India’s international fixtures from bcci.tv.

# %%
# !pip install pandas
# !pip install --upgrade selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome()
driver.get("http://www.bcci.tv/")

time.sleep(5)

closepopup = driver.find_element(By.XPATH,'//button[@class="close-button page-close"]')
closepopup.click()

time.sleep(3)
clickoncategory = driver.find_element(By.XPATH, '//*[@id="imw-international-men"]/a[2]')
clickoncategory.click()

# %%
cric_series = []
cric_place = []
cric_date = []
cric_time = []

series = driver.find_elements(By.XPATH,'//h5[@class="match-tournament-name ng-binding"]')

for i in series[0:211]:
    seriesname = i.text
    cric_series.append(seriesname)
    
#cric_series

place = driver.find_elements(By.XPATH,'//div[@class="match-place ng-scope"]')

for i in place[0:211]:
    placename = i.text
    cric_place.append(placename)
    
#cric_place


date = driver.find_elements(By.XPATH,'//div[@class="match-dates ng-binding"]')

for i in date[0:211]:
    seriesdate = i.text
    cric_date.append(seriesdate)
    
#cric_date


time = driver.find_elements(By.XPATH,'//div[@class="match-time no-margin ng-binding"]')

for i in time[0:211]:
    seriestime = i.text
    cric_time.append(seriestime)
    
#cric_time

# %%
print(len(cric_series),len(cric_place),len(cric_date),len(cric_time))
# Out:
# 211 211 211 211

# %%
df = pd.DataFrame({'Series':cric_series, 'Place':cric_place, 'Date':cric_date, 'Time':cric_time})
df
# Out:
#                           Series  \
# 0        ICC MENS WORLD CUP 2023
# 1        ICC MENS WORLD CUP 2023
# 2        ICC MENS WORLD CUP 2023
# 3        ICC MENS WORLD CUP 2023
# 4        ICC MENS WORLD CUP 2023
# ..                           ...
# 206                ASIA CUP 2022
# 207                ASIA CUP 2022
# 208  NEW ZEALAND A TOUR OF INDIA
# 209                ASIA CUP 2022
# 210                ASIA CUP 2022
#
#                                                  Place               Date  \
# 0        Maharashtra Cricket Association Stadium, Pune   19 OCTOBER, 2023
# 1    Himachal Pradesh Cricket Association Stadium, ...   22 OCTOBER, 2023
# 2    Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...   29 OCTOBER, 2023
# 3                             Wankhede Stadium, Mumbai   2 NOVEMBER, 2023
# 4                                Eden Gardens, Kolkata   5 NOVEMBER, 2023
# ..                                                 ...                ...
# ...
